# %% [markdown]
# <a href="https://colab.research.google.com/github/Mao925/Natural-Language-Processing-with-disaster-tweets/blob/main/NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# =========================
# 1. CSVファイルの読み込み
# =========================

train_path = "/content/drive/MyDrive/Kaggle/NLP/train.csv"
test_path  = "/content/drive/MyDrive/Kaggle/NLP/test.csv"

train = pd.read_csv(train_path)
test = pd.read_csv(test_path)

print("読み込み完了")
print("train shape:", train.shape)
print("test shape :", test.shape)


# =========================
# 2. 先頭データの確認
# =========================

print("\n===== train head =====")
display(train.head())

print("\n===== test head =====")
display(test.head())


# =========================
# 3. カラム一覧の確認
# =========================

print("\n===== train columns =====")
print(train.columns.tolist())

print("\n===== test columns =====")
print(test.columns.tolist())


# =========================
# 4. データ型・欠損値の確認
# =========================

print("\n===== train info =====")
train.info()

print("\n===== test info =====")
test.info()

print("\n===== train missing values =====")
display(train.isnull().sum().sort_values(ascending=False))

print("\n===== test missing values =====")
display(test.isnull().sum().sort_values(ascending=False))


# =========================
# 5. 重複行の確認
# =========================

print("\n===== duplicated rows =====")
print("train duplicated:", train.duplicated().sum())
print("test duplicated :", test.duplicated().sum())


# =========================
# 6. 数値データの統計量
# =========================

print("\n===== train describe numerical =====")
display(train.describe())

print("\n===== test describe numerical =====")
display(test.describe())


# =========================
# 7. 文字列カラムの確認
# =========================

text_cols_train = train.select_dtypes(include="object").columns.tolist()
text_cols_test = test.select_dtypes(include="object").columns.tolist()

print("\n===== object columns =====")
print("train object columns:", text_cols_train)
print("test object columns :", text_cols_test)

for col in text_cols_train:
    print(f"\n===== train: {col} sample =====")
    display(train[col].head(10))
    print("文字数の統計:")
    display(train[col].astype(str).str.len().describe())


# =========================
# 8. 目的変数っぽいカラムの分布確認
# =========================

possible_target_cols = ["target", "label", "class", "sentiment", "y"]

for col in possible_target_cols:
    if col in train.columns:
        print(f"\n===== target distribution: {col} =====")
        display(train[col].value_counts())
        display(train[col].value_counts(normalize=True))
# Out:
# 読み込み完了
# train shape: (7613, 5)
# test shape : (3263, 4)
#
# ===== train head =====
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
# ===== test head =====
#    id keyword location                                               text
# 0   0     NaN      NaN                 Just happened a terrible car crash
# 1   2     NaN      NaN  Heard about #earthquake is different cities, s...
# 2   3     NaN      NaN  there is a forest fire at spot pond, geese are...
# ...

# %%
import pandas as pd
import re
import html
from urllib.parse import unquote

# =========================
# 1. CSVファイルの読み込み
# =========================

train_path = "/content/drive/MyDrive/Kaggle/NLP/train.csv"
test_path = "/content/drive/MyDrive/Kaggle/NLP/test.csv"

train = pd.read_csv(train_path)
test = pd.read_csv(test_path)

print("読み込み完了")
print("train shape:", train.shape)
print("test shape :", test.shape)


# =========================
# 2. 必要カラムの確認
# =========================

required_train_cols = ["id", "keyword", "location", "text", "target"]
required_test_cols = ["id", "keyword", "location", "text"]

missing_train_cols = [col for col in required_train_cols if col not in train.columns]
missing_test_cols = [col for col in required_test_cols if col not in test.columns]

if missing_train_cols:
    raise ValueError(f"train.csvに存在しないカラムがあります: {missing_train_cols}")

if missing_test_cols:
    raise ValueError(f"test.csvに存在しないカラムがあります: {missing_test_cols}")


# =========================
# 3. 軽いテキストクリーニング関数
# =========================

def clean_text_for_tfidf(text):
    """
    TF-IDF + LogisticRegression向けの軽いクリーニング。
    過剰な正規化はせず、単語情報をできるだけ残す。
    """
    if pd.isna(text):
        return ""

    text = str(text)

    # HTMLエスケープを戻す
    text = html.unescape(text)

    # URLエンコードを戻す
    # 例: body%20bags -> body bags
    text = unquote(text)

    # 小文字化
    text = text.lower()

    # URLを <url> に置換
    text = re.sub(r"https?://\S+|www\.\S+", " <url> ", text)

    # メンションを <user> に置換
    text = re.sub(r"@\w+", " <user> ", text)

    # ハッシュタグは # だけ削除して単語は残す
    text = re.sub(r"#", "", text)

    # 連続する空白を1つにまとめる
    text = re.sub(r"\s+", " ", text)

    # 前後の空白を削除
    text = text.strip()

    return text


# =========================
# 4. train / test に同じ前処理を適用
# =========================

train_processed = train.copy()
test_processed = test.copy()

# keywordの欠損値は空文字で補完
train_processed["keyword"] = train_processed["keyword"].fillna("")
test_processed["keyword"] = test_processed["keyword"].fillna("")

# textにも念のため欠損対応
train_processed["text"] = train_processed["text"].fillna("")
test_processed["text"] = test_processed["text"].fillna("")

# keywordとtextをクリーニング
train_processed["keyword_clean"] = train_processed["keyword"].apply(clean_text_for_tfidf)
test_processed["keyword_clean"] = test_processed["keyword"].apply(clean_text_for_tfidf)

train_processed["text_clean"] = train_processed["text"].apply(clean_text_for_tfidf)
test_processed["text_clean"] = test_processed["text"].apply(clean_text_for_tfidf)

# keyword_clean と text_clean を結合して input_text を作成
train_processed["input_text"] = (
    train_processed["keyword_clean"] + " " + train_processed["text_clean"]
).str.strip()

test_processed["input_text"] = (
    test_processed["keyword_clean"] + " " + test_processed["text_clean"]
).str.strip()


# =========================
# 5. 確認
# =========================

print("\n===== train_processed head =====")
display(train_processed.head())

print("\n===== test_processed head =====")
display(test_processed.head())

print("\n===== train_processed missing values =====")
display(train_processed.isnull().sum().sort_values(ascending=False))

print("\n===== test_processed missing values =====")
display(test_processed.isnull().sum().sort_values(ascending=False))

print("\n===== input_text samples: train =====")
display(train_processed[["id", "keyword", "keyword_clean", "text", "text_clean", "input_text", "target"]].head(10))

print("\n===== input_text samples: test =====")
display(test_processed[["id", "keyword", "keyword_clean", "text", "text_clean", "input_text"]].head(10))

print("\n===== target distribution =====")
display(train_processed["target"].value_counts())
display(train_processed["target"].value_counts(normalize=True))

print("\n前処理完了")
print("train_processed shape:", train_processed.shape)
print("test_processed shape :", test_processed.shape)
# Out:
# 読み込み完了
# train shape: (7613, 5)
# test shape : (3263, 4)
#
# ===== train_processed head =====
#    id keyword location                                               text  \
# 0   1              NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4              NaN             Forest fire near La Ronge Sask. Canada
# 2   5              NaN  All residents asked to 'shelter in place' are ...
# 3   6              NaN  13,000 people receive #wildfires evacuation or...
# 4   7              NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target keyword_clean                                         text_clean  \
# 0       1                our deeds are the reason of this earthquake ma...
# 1       1                           forest fire near la ronge sask. canada
# 2       1                all residents asked to 'shelter in place' are ...
# 3       1                13,000 people receive wildfires evacuation ord...
# ...

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import (
    accuracy_score,
    f1_score,
    classification_report,
    confusion_matrix
)

# =========================
# 1. 使用するデータの準備
# =========================

# 前処理済みの input_text を使用
X = train_processed["input_text"].fillna("")
y = train_processed["target"].astype(int)

X_test = test_processed["input_text"].fillna("")

print("X shape:", X.shape)
print("y shape:", y.shape)
print("X_test shape:", X_test.shape)

print("\n===== target distribution =====")
display(y.value_counts())
display(y.value_counts(normalize=True))


# =========================
# 2. 学習用データ / 検証用データに分割
# =========================

X_train, X_valid, y_train, y_valid = train_test_split(
    X,
    y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

print("\n===== split result =====")
print("X_train:", X_train.shape)
print("X_valid:", X_valid.shape)
print("y_train:", y_train.shape)
print("y_valid:", y_valid.shape)


# =========================
# 3. TF-IDF + LogisticRegression Pipeline
# =========================

model = Pipeline([
    (
        "tfidf",
        TfidfVectorizer(
            ngram_range=(1, 2),
            min_df=2,
            max_df=0.95,
            sublinear_tf=True
        )
    ),
    (
        "logreg",
        LogisticRegression(
            max_iter=1000,
            C=1.0,
            random_state=42
        )
    )
])


# =========================
# 4. モデル学習
# =========================

model.fit(X_train, y_train)

print("\n学習完了")


# =========================
# 5. 検証データで予測
# =========================

valid_pred = model.predict(X_valid)

accuracy = accuracy_score(y_valid, valid_pred)
f1 = f1_score(y_valid, valid_pred)

print("\n===== validation score =====")
print("accuracy:", accuracy)
print("f1_score:", f1)

print("\n===== classification report =====")
print(classification_report(y_valid, valid_pred))

print("\n===== confusion matrix =====")
cm = confusion_matrix(y_valid, valid_pred)
cm_df = pd.DataFrame(
    cm,
    index=["actual_0", "actual_1"],
    columns=["pred_0", "pred_1"]
)
display(cm_df)


# =========================
# 6. testデータに対して予測
# =========================

test_pred = model.predict(X_test)

print("\n===== test prediction distribution =====")
display(pd.Series(test_pred).value_counts())
display(pd.Series(test_pred).value_counts(normalize=True))


# =========================
# 7. Kaggle提出用CSVを作成
# =========================

submission = pd.DataFrame({
    "id": test_processed["id"],
    "target": test_pred.astype(int)
})

submission_path = "submission_tfidf_logreg.csv"
submission.to_csv(submission_path, index=False)

print("\n提出用CSVを作成しました:", submission_path)

print("\n===== submission head =====")
display(submission.head())

print("\n===== submission shape =====")
print(submission.shape)


# =========================
# 8. 改善候補メモ
# =========================

# 改善候補1:
# char-level TF-IDFを追加する
# 例: analyzer="char_wb", ngram_range=(3, 5)
#
# 改善候補2:
# LogisticRegressionのCを調整する
# 例: C=0.5, 1.0, 2.0, 3.0 など
#
# 改善候補3:
# class_weight="balanced" を試す
#
# 改善候補4:
# word TF-IDF と char TF-IDF を FeatureUnion で結合する
# Out:
# X shape: (7613,)
# y shape: (7613,)
# X_test shape: (3263,)
#
# ===== target distribution =====
# target
# 0    4342
# 1    3271
# Name: count, dtype: int64
# target
# 0    0.57034
# 1    0.42966
# Name: proportion, dtype: float64
# ===== split result =====
# X_train: (6090,)
# X_valid: (1523,)
# y_train: (6090,)
# y_valid: (1523,)
#
# 学習完了
#
# ===== validation score =====
# accuracy: 0.8102429415627052
# f1_score: 0.7633087633087633
#
# ===== classification report =====
#               precision    recall  f1-score   support
#
#            0       0.80      0.88      0.84       869
#            1       0.82      0.71      0.76       654
#
#     accuracy                           0.81      1523
#    macro avg       0.81      0.80      0.80      1523
# weighted avg       0.81      0.81      0.81      1523
#
#
# ===== confusion matrix =====
#           pred_0  pred_1
# actual_0     768     101
# actual_1     188     466
# ===== test prediction distribution =====
# 0    2125
# ...
